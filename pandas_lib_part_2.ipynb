# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('car_data.csv')
df
# Out:
#       car_name  price($) date_of_sold  mileage condition  meter_reading  \
# 0  Lamborghini  1,74,390     12/09/16      3.5      good          75625
# 1  Lamborghini  1,19,780     29/07/19      4.5    better          45400
# 2       Porsch     97400     17/03/11      NaN      Best          25000
# 3   Honda City     71432          NaN     12.0       bad         125000
#
#         model
# 0    LP 640-4
# 1    LP 580-2
# 2  Porsch 911
# 3        2006

# %%
df.dtypes
# Out:
# car_name          object
# price($)          object
# date_of_sold      object
# mileage          float64
# condition         object
# meter_reading      int64
# model             object
# dtype: object

# %%
df.head()
# Out:
#       car_name  price($) date_of_sold  mileage condition  meter_reading  \
# 0  Lamborghini  1,74,390     12/09/16      3.5      good          75625
# 1  Lamborghini  1,19,780     29/07/19      4.5    better          45400
# 2       Porsch     97400     17/03/11      NaN      Best          25000
# 3   Honda City     71432          NaN     12.0       bad         125000
#
#         model
# 0    LP 640-4
# 1    LP 580-2
# 2  Porsch 911
# 3        2006

# %%
df.head(2)
# Out:
#       car_name  price($) date_of_sold  mileage condition  meter_reading  \
# 0  Lamborghini  1,74,390     12/09/16      3.5      good          75625
# 1  Lamborghini  1,19,780     29/07/19      4.5    better          45400
#
#       model
# 0  LP 640-4
# 1  LP 580-2

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.to_numpy()
# Out:
# array([['Lamborghini', '1,74,390', '12/09/16', 3.5, 'good', 75625,
#         'LP 640-4'],
#        ['Lamborghini', '1,19,780', '29/07/19', 4.5, 'better', 45400,
#         'LP 580-2'],
#        ['Porsch', '97400', '17/03/11', nan, 'Best', 25000, 'Porsch 911'],
#        ['Honda City', '71432', nan, 12.0, 'bad', 125000, '2006']],
#       dtype=object)

# %%
df
# Out:
#       car_name  price($) date_of_sold  mileage condition  meter_reading  \
# 0  Lamborghini  1,74,390     12/09/16      3.5      good          75625
# 1  Lamborghini  1,19,780     29/07/19      4.5    better          45400
# 2       Porsch     97400     17/03/11      NaN      Best          25000
# 3   Honda City     71432          NaN     12.0       bad         125000
#
#         model
# 0    LP 640-4
# 1    LP 580-2
# 2  Porsch 911
# 3        2006

# %%
df.describe()
# Out:
#          mileage  meter_reading
# count   3.000000       4.000000
# mean    6.666667   67756.250000
# std     4.645787   43461.335187
# min     3.500000   25000.000000
# 25%     4.000000   40300.000000
# 50%     4.500000   60512.500000
# 75%     8.250000   87968.750000
# max    12.000000  125000.000000

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#       car_name condition date_of_sold  meter_reading  mileage       model  \
# 0  Lamborghini      good     12/09/16          75625      3.5    LP 640-4
# 1  Lamborghini    better     29/07/19          45400      4.5    LP 580-2
# 2       Porsch      Best     17/03/11          25000      NaN  Porsch 911
# 3   Honda City       bad          NaN         125000     12.0        2006
#
#    price($)
# 0  1,74,390
# 1  1,19,780
# 2     97400
# 3     71432

# %%
df.sort_values('price',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-7e1a1afefabb> in <module>
# ----> 1 df.sort_values('price',ascending=False)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4991
#    4992             by = by[0]
# -> 4993             k = self._get_label_or_level_values(by, axis=axis)
#    4994
#    4995             if isinstance(ascending, (tuple, list)):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 'price'

# %%
df['car_name']
# Out:
# 0    Lamborghini
# 1    Lamborghini
# 2         Porsch
# 3     Honda City
# Name: car_name, dtype: object

# %%
df.car_name
# Out:
# 0    Lamborghini
# 1    Lamborghini
# 2         Porsch
# 3     Honda City
# Name: car_name, dtype: object

# %%
df2 = df[0:3]
df2
# Out:
#       car_name  price($) date_of_sold  mileage condition  meter_reading  \
# 0  Lamborghini  1,74,390     12/09/16      3.5      good          75625
# 1  Lamborghini  1,19,780     29/07/19      4.5    better          45400
# 2       Porsch     97400     17/03/11      NaN      Best          25000
#
#         model
# 0    LP 640-4
# 1    LP 580-2
# 2  Porsch 911

# %%
df[df.meter_reading>46000]
# Out:
#       car_name  price($) date_of_sold  mileage condition  meter_reading  \
# 0  Lamborghini  1,74,390     12/09/16      3.5      good          75625
# 3   Honda City     71432          NaN     12.0       bad         125000
#
#       model
# 0  LP 640-4
# 3      2006

# %%
copied_df = df.copy()
copied_df
# Out:
#       car_name  price($) date_of_sold  mileage condition  meter_reading  \
# 0  Lamborghini  1,74,390     12/09/16      3.5      good          75625
# 1  Lamborghini  1,19,780     29/07/19      4.5    better          45400
# 2       Porsch     97400     17/03/11      NaN      Best          25000
# 3   Honda City     71432          NaN     12.0       bad         125000
#
#         model
# 0    LP 640-4
# 1    LP 580-2
# 2  Porsch 911
# 3        2006

# %%
copied_df['current_price($)'] = ['274000','200150','150000','120012']
copied_df
# Out:
#       car_name  price($) date_of_sold  mileage condition  meter_reading  \
# 0  Lamborghini  1,74,390     12/09/16      3.5      good          75625
# 1  Lamborghini  1,19,780     29/07/19      4.5    better          45400
# 2       Porsch     97400     17/03/11      NaN      Best          25000
# 3   Honda City     71432          NaN     12.0       bad         125000
#
#         model current_price($)
# 0    LP 640-4           274000
# 1    LP 580-2           200150
# 2  Porsch 911           150000
# 3        2006           120012

# %%
copied_df.dropna(how='any')
# Out:
#       car_name  price($) date_of_sold  mileage condition  meter_reading  \
# 0  Lamborghini  1,74,390     12/09/16      3.5      good          75625
# 1  Lamborghini  1,19,780     29/07/19      4.5    better          45400
#
#       model current_price($)
# 0  LP 640-4           274000
# 1  LP 580-2           200150

# %%
copied_df.fillna(value=5)
# Out:
#       car_name  price($) date_of_sold  mileage condition  meter_reading  \
# 0  Lamborghini  1,74,390     12/09/16      3.5      good          75625
# 1  Lamborghini  1,19,780     29/07/19      4.5    better          45400
# 2       Porsch     97400     17/03/11      5.0      Best          25000
# 3   Honda City     71432            5     12.0       bad         125000
#
#         model current_price($)
# 0    LP 640-4           274000
# 1    LP 580-2           200150
# 2  Porsch 911           150000
# 3        2006           120012
